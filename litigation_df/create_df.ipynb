# %%
import pandas as pd
from rapidfuzz import fuzz, process

# %%
decisions = pd.read_csv('decisions_df.csv', encoding='cp1252')

# %%
decisions.columns
# Out:
# Index(['gvkey', 'Name', 'sector_name', 'carbon_major', 'date', 'case',
#        'impact', 'country', 'region', 'Positive or negative', 'Column1',
#        'Column2'],
#       dtype='object')

# %%
#remove column1 and column 2
decisions = decisions.drop(columns=['Column1', 'Column2'])

# %%
decisions.isnull().sum()
# Out:
# gvkey                   150
# Name                      0
# sector_name             149
# carbon_major            150
# date                      1
# case                      1
# impact                  150
# country                 150
# region                  150
# Positive or negative    108
# dtype: int64

# %%
decisions = decisions.drop(columns = ['gvkey', 'sector_name', 'carbon_major', 'country', 'region'])

# %%
decisions
# Out:
#                             Name        date  \
# 0             Williams Companies   9/30/2021
# 1              Royal Dutch Shell    6/8/2020
# 2                        Ryanair    2/5/2020
# 3                  De Longhi Spa   4/29/2008
# 4              General Motors Co   9/18/2008
# ..                           ...         ...
# 252                Volkswagen AG  11/16/2023
# 253  Bayerische Motoren Werke AG    2/7/2024
# 254               Air France KLM   12/6/2023
# 255        Deutsche Lufthansa AG   12/6/2023
# 256                            0         NaN
#
#                                                   case  impact  \
# 0    Adorers of the Blood of Christ v. Transcontine...     3.0
# 1    Advertising Standards Authority's Ruling on Sh...    -3.0
# 2            ASA Ruling on Ryanair Ltd t/a Ryanair Ltd    -3.0
# 3    Australian Competition & Consumer Commission v...    -3.0
# 4    Australian Competition & Consumer Commission v...    -3.0
# ..                                                 ...     ...
# 252  Altroconsumo v. Volkswagen Aktiengesellschaft ...     NaN
# 253                         ASA Ruling on BMW (UK) Ltd     NaN
# 254                       ASA Ruling on Air France KLM     NaN
# 255   ASA Ruling on Lufthansa (complaint no.2 in 2023)     NaN
# 256                                                NaN     NaN
#
#     Positive or negative
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 252             Negative
# 253             Negative
# 254             Negative
# 255             Negative
# 256                  NaN
#
# [257 rows x 5 columns]

# %%
filings = pd.read_csv('original_df.csv', encoding='cp1252')

# %%
filings.columns
# Out:
# Index(['gvkey', 'Name', 'sector_name', 'carbon_major', 'date', 'case',
#        'country', 'region', 'novel', 'courtlaw', 'govplaintiff', 'interest',
#        'damages', 'major_changes', 'novel_weight', 'courtlaw_weight',
#        'govplaintiff_weight', 'interest_weight', 'damages_weight',
#        'major_weight', 'profile_sum', 'Unnamed: 21', '2004-01-01',
#        '2005-01-01', '2006-01-01', '2007-01-01', '2008-01-01', '2009-01-01',
#        '2010-01-01', '2011-01-01', '2012-01-01', '2013-01-01', '2014-01-01',
#        '2015-01-01', '2016-01-01', '2017-01-01', '2018-01-01', '2019-01-01',
#        '2020-01-01', '2021-01-01', '2022-01-01', '2023-01-01', '2024-01-01',
#        '2025-01-01', 'Unnamed: 44', 'name', 'country.1', 'region.1',
#        'gic_sector', 'Total # filings', 'Unnamed: 50', '2004-01-01.1',
#        '2005-01-01.1', '2006-01-01.1', '2007-01-01.1', '2008-01-01.1',
#        '2009-01-01.1', '2010-01-01.1', '2011-01-01.1', '2012-01-01.1',
#        '2013-01-01.1', '2014-01-01.1', '2015-01-01.1', '2016-01-01.1',
#        '2017-01-01.1', '2018-01-01.1', '2019-01-01.1', '2020-01-01.1',
#        '2021-01-01.1', '2022-01-01.1', '2023-01-01.1', '2024-01-01.1',
#        'Unnamed: 72', 'Unnamed: 73', 'Unnamed: 74', 'Unnamed: 75',
#        'Unnamed: 76', 'Unnamed: 77', 'Unnamed: 78', 'Unnamed: 79',
#        'Unnamed: 80', 'Unnamed: 81', 'Unnamed: 82', 'Unnamed: 83',
#        'Unnamed: 84', 'Unnamed: 85', 'Unnamed: 86', 'Unnamed: 87',
#        'Unnamed: 88', 'Unnamed: 89', 'Unnamed: 90', 'Unnamed: 91',
#        'Unnamed: 92', 'Unnamed: 93'],
#       dtype='object')

# %%
columns_to_keep = ['Name', 'date', 'case']
filings = filings[columns_to_keep]

# %%
#remove rows after 397 
filings = filings.iloc[:396]

# %%
#rename date column to 'date_filing'
filings = filings.rename(columns={'date': 'date_filing'})

decisions = decisions.rename(columns={'date': 'date_decision'})

# %%
decisions
# Out:
#                             Name date_decision  \
# 0             Williams Companies     9/30/2021
# 1              Royal Dutch Shell      6/8/2020
# 2                        Ryanair      2/5/2020
# 3                  De Longhi Spa     4/29/2008
# 4              General Motors Co     9/18/2008
# ..                           ...           ...
# 252                Volkswagen AG    11/16/2023
# 253  Bayerische Motoren Werke AG      2/7/2024
# 254               Air France KLM     12/6/2023
# 255        Deutsche Lufthansa AG     12/6/2023
# 256                            0           NaN
#
#                                                   case  impact  \
# 0    Adorers of the Blood of Christ v. Transcontine...     3.0
# 1    Advertising Standards Authority's Ruling on Sh...    -3.0
# 2            ASA Ruling on Ryanair Ltd t/a Ryanair Ltd    -3.0
# 3    Australian Competition & Consumer Commission v...    -3.0
# 4    Australian Competition & Consumer Commission v...    -3.0
# ..                                                 ...     ...
# 252  Altroconsumo v. Volkswagen Aktiengesellschaft ...     NaN
# 253                         ASA Ruling on BMW (UK) Ltd     NaN
# 254                       ASA Ruling on Air France KLM     NaN
# 255   ASA Ruling on Lufthansa (complaint no.2 in 2023)     NaN
# 256                                                NaN     NaN
#
#     Positive or negative
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 252             Negative
# 253             Negative
# 254             Negative
# 255             Negative
# 256                  NaN
#
# [257 rows x 5 columns]

# %%
filings
# Out:
#                         Name date_filing  \
# 0    American Electric Power   7/21/2004
# 1          General Motors Co   9/20/2006
# 2                 Volkswagen    5/7/2007
# 3          General Motors Co   1/16/2008
# 4                Duke Energy   2/12/2008
# ..                       ...         ...
# 391          Delta Air Lines  11/30/2023
# 392                Repsol SA   2/21/2024
# 393                ING Group   1/19/2024
# 394                      AIG   8/10/2022
# 395                  Eni Spa   2/14/2022
#
#                                                   case
# 0                       Connecticut v. Am. Elec. Power
# 1                               California v. GM Corp.
# 2                           Germanwatch vs. Volkswagen
# 3    Australian Competition & Consumer Commission v...
# 4                  Sierra Club v. Duke Energy Indiana
# ..                                                 ...
# 391  Complaint against Virgin Atlantic and British ...
# 392                    Iberdrola and others vs. Repsol
# 393                         Milieudefensie v. ING Bank
# 394  Aloha Petroleum Ltd. v. National Union Fire In...
# 395  Rete Legalità per il Clima (Legality for Clima...
#
# [396 rows x 3 columns]

# %%
import re
import unicodedata

def clean_text(text, 
               lowercase=True, 
               remove_punctuation=False, 
               remove_numbers=False, 
               strip_non_ascii=True, 
               normalize_unicode=True):
    """Standardized text cleaning function with configurable options."""
    
    if not isinstance(text, str):
        return text  # Return as-is if it's not a string

    if normalize_unicode:
        text = unicodedata.normalize('NFKC', text)
    
    if lowercase:
        text = text.lower()

    if strip_non_ascii:
        text = text.encode('ascii', 'ignore').decode('ascii')
        
    if remove_punctuation:
        text = re.sub(r'[^\w\s]', '', text)

    if remove_numbers:
        text = re.sub(r'\d+', '', text)

    text = re.sub(r'\s+', ' ', text)  # Collapse multiple spaces
    text = text.strip()               # Remove leading/trailing spaces
    
    return text

# %%
filings['cleaned_name'] = filings['case'].apply(clean_text,
    lowercase=True, 
    remove_punctuation=True, 
    remove_numbers=True, 
    strip_non_ascii=True, 
    normalize_unicode=True
)
decisions['cleaned_name'] = decisions['case'].apply(clean_text,
    lowercase=True, 
    remove_punctuation=True, 
    remove_numbers=True, 
    strip_non_ascii=True, 
    normalize_unicode=True
)

# %%
filings['cleaned_full'] = filings['cleaned_name'] + " " + filings['Name'].fillna('').apply(clean_text)
decisions['cleaned_full'] = decisions['cleaned_name'] + " " + decisions['Name'].fillna('').apply(clean_text)

# %%
def fuzzy_merge(df1, df2, key1, key2, threshold=80):
    s = df2[key2].tolist()

    matches = df1[key1].apply(
        lambda x: process.extractOne(x, s, scorer=fuzz.token_sort_ratio, score_cutoff=threshold)
    )

    df1['best_match'] = matches.apply(lambda x: x[0] if x else None)
    df1['match_score'] = matches.apply(lambda x: x[1] if x else None)

    # Debug non-perfect matches
    print("Sample non-perfect matches:")
    display(df1[df1['match_score'] < 100][['case', 'best_match', 'match_score']])

    # Merge based on best match
    merged = df1.merge(df2, left_on='best_match', right_on=key2, how='left')
    
    return merged

# %%
merged = fuzzy_merge(
    df1=filings.copy(),
    df2=decisions.copy(),
    key1='cleaned_full',
    key2='cleaned_full',
    threshold=85
)
# Out:
# Sample non-perfect matches:
#                                                   case  \
# 105                      City of New York v. BP p.l.c.
# 296                      Kaiser et al v. Volkswagen AG
# 319                     Berrin v. Delta Air Lines Inc.
# 320  Long v. Koninklijke Luchtvaart Maatschappij, N.V.
# 323  Simijanovic v. Koninklijke Luchtvaart Maatscha...
# 332  ASA Ruling on Shell UK Ltd (following a compla...
# 345  Sierra Club Canada Foundation et al. v. Minist...
# 347                    Allhoff Cramer v. Volkswagen AG
# 349  Church of England Pensions Board and others v....
#
#                                             best_match  match_score
# 105                       city of new york v bp plc bp    85.245902
# 296         kaiser et al v volkswagen ag volkswagen ag    96.296296
# 319   berrin v delta air lines inc delta air lines inc    95.652174
# 320  long v koninklijke luchtvaart maatschappij nv ...    97.560976
# 323  dakus v koninklijke luchtvaart maatschappij nv...    86.567164
# 332  asa ruling on shell uk ltd following a complai...    92.405063
# 345  sierra club canada foundation et al v minister...    98.058252
# 347       allhoff cramer v volkswagen ag volkswagen ag    96.470588
# 349  church of england pensions board and others v ...    97.902098

# %%
columns_to_drop =['cleaned_name_x', 'cleaned_full_x', 'best_match', 'match_score', 'cleaned_name_y', 'cleaned_full_y']
merged = merged.drop(columns=columns_to_drop)

# %%
column_order = ['Name_x', 'Name_y', 'case_x', 'case_y', 'date_filing', 'date_decision', 'impact', 'Positive or negative']

merged = merged[column_order]

# %%
merged
# Out:
#                       Name_x                   Name_y  \
# 0    American Electric Power  American Electric Power
# 1    American Electric Power  American Electric Power
# 2          General Motors Co        General Motors Co
# 3          General Motors Co        General Motors Co
# 4                 Volkswagen               Volkswagen
# ..                       ...                      ...
# 446          Delta Air Lines                        0
# 447                Repsol SA                Repsol SA
# 448                ING Group                        0
# 449                      AIG                      AIG
# 450                  Eni Spa                        0
#
#                                                 case_x  \
# 0                       Connecticut v. Am. Elec. Power
# 1                       Connecticut v. Am. Elec. Power
# 2                               California v. GM Corp.
# 3                               California v. GM Corp.
# 4                           Germanwatch vs. Volkswagen
# ..                                                 ...
# 446  Complaint against Virgin Atlantic and British ...
# 447                    Iberdrola and others vs. Repsol
# 448                         Milieudefensie v. ING Bank
# 449  Aloha Petroleum Ltd. v. National Union Fire In...
# 450  Rete Legalità per il Clima (Legality for Clima...
#
#                                                 case_y date_filing  \
# 0                       Connecticut v. Am. Elec. Power   7/21/2004
# 1                       Connecticut v. Am. Elec. Power   7/21/2004
# 2                               California v. GM Corp.   9/20/2006
# 3                               California v. GM Corp.   9/20/2006
# 4                           Germanwatch vs. Volkswagen    5/7/2007
# ..                                                 ...         ...
# 446                                                NaN  11/30/2023
# 447                    Iberdrola and others vs. Repsol   2/21/2024
# 448                                                NaN   1/19/2024
# 449  Aloha Petroleum Ltd. v. National Union Fire In...   8/10/2022
# 450                                                NaN   2/14/2022
#
#     date_decision  impact Positive or negative
# 0       6/20/2011     3.0                  NaN
# 1       5/13/2010     3.0                  NaN
# 2       6/24/2009     3.0                  NaN
# 3       9/17/2007     3.0                  NaN
# 4      11/20/2007     3.0                  NaN
# ..            ...     ...                  ...
# 446           NaN     NaN                  NaN
# 447     4/16/2024     NaN             Positive
# 448           NaN     NaN                  NaN
# 449     10/7/2024     NaN             Positive
# 450           NaN     NaN                  NaN
#
# [451 rows x 8 columns]

# %%
#save to csv 
merged.to_csv('merged_decisions.csv', index=False, encoding='utf-8-sig')

# %%
merged
# Out:
#                       Name_x                   Name_y  \
# 0    American Electric Power  American Electric Power
# 1    American Electric Power  American Electric Power
# 2          General Motors Co        General Motors Co
# 3          General Motors Co        General Motors Co
# 4                 Volkswagen               Volkswagen
# ..                       ...                      ...
# 446          Delta Air Lines                        0
# 447                Repsol SA                Repsol SA
# 448                ING Group                        0
# 449                      AIG                      AIG
# 450                  Eni Spa                        0
#
#                                                 case_x  \
# 0                       Connecticut v. Am. Elec. Power
# 1                       Connecticut v. Am. Elec. Power
# 2                               California v. GM Corp.
# 3                               California v. GM Corp.
# 4                           Germanwatch vs. Volkswagen
# ..                                                 ...
# 446  Complaint against Virgin Atlantic and British ...
# 447                    Iberdrola and others vs. Repsol
# 448                         Milieudefensie v. ING Bank
# 449  Aloha Petroleum Ltd. v. National Union Fire In...
# 450  Rete Legalità per il Clima (Legality for Clima...
#
#                                                 case_y date_filing  \
# 0                       Connecticut v. Am. Elec. Power   7/21/2004
# 1                       Connecticut v. Am. Elec. Power   7/21/2004
# 2                               California v. GM Corp.   9/20/2006
# 3                               California v. GM Corp.   9/20/2006
# 4                           Germanwatch vs. Volkswagen    5/7/2007
# ..                                                 ...         ...
# 446                                                NaN  11/30/2023
# 447                    Iberdrola and others vs. Repsol   2/21/2024
# 448                                                NaN   1/19/2024
# 449  Aloha Petroleum Ltd. v. National Union Fire In...   8/10/2022
# 450                                                NaN   2/14/2022
#
#     date_decision  impact Positive or negative
# 0       6/20/2011     3.0                  NaN
# 1       5/13/2010     3.0                  NaN
# 2       6/24/2009     3.0                  NaN
# 3       9/17/2007     3.0                  NaN
# 4      11/20/2007     3.0                  NaN
# ..            ...     ...                  ...
# 446           NaN     NaN                  NaN
# 447     4/16/2024     NaN             Positive
# 448           NaN     NaN                  NaN
# 449     10/7/2024     NaN             Positive
# 450           NaN     NaN                  NaN
#
# [451 rows x 8 columns]

# %%
for name in merged.Name_x.unique():
    print(name)
# Out:
# American Electric Power
# General Motors Co
# Volkswagen
# Duke Energy
# BP
# Chevron
# ExxonMobil
# Royal Dutch Shell
# Peabody
# Dominion Energy
# United Airlines Holdings Inc
# Delta Air Lines
# Murphy Oil Corp
# Honeywell International
# Equinor
# Walmart Inc
# Flughafen Wien
# Global Partners
# Costco Wholesale Corp
# US Steel
# Arch Resources
# Hess Corp
# APA Corp
# Marathon Oil
# Occidental
# Conocophillips
# Ovintiv Inc
# Anadarko
# Husky Energy
# Devon Energy Corp
# Suncor Energy
# Repsol SA
# Anglo America
# Rio Tinto
# Total Energies SE
# Eni Spa
# Heidelberg Cement
# RWE
# CNX Resources
# Glencore
# Sempra Energy
# ING Group
# Marathon Petroleum
# Arkema
# Phillips 66
# Consol Energy
# Powszechny Zak?ad Ubezpiecze?
# Keurig Dr Pepper Inc.
# Enea SA
# Edison International
# TransDigm Group
# Innospec
# PG&E
# PGE SA
# Energy Transfers
# Ascent Resources
# NorthWestern Corp
# Bloom Energy Corp
# Williams Companies
# Groupe Casino
# The Coca-Cola Company
# The Clorox Co
# Proctor & Gamble
# Nestle
# Campbell Soup Company
# L'Oreal
# Colgate-Palmolive Co
# Danimer Scientific
# Oatly
# Sunoco LP
# HSBC
# Entergy Corp
# BMW
# Mercedes-Benz AG
# Owens Corning Corporation
# Alon USA
# The AES Corporation
# NGL Energy Partners LP
# Talen Energy Corporation
# Ashland Inc
# Brookfield Renewable Partners
# National Grid PLC
# Allbirds, Inc
# Goodyear Tire & Rubber Co
# Xstrata PLC
# Kobe Steel Ltd
# Mitsubishi UFJ
# Financial Group, Inc.
# General Electric
# BASF SE
# Air France KLM SA
# Etsy Inc.
# Enviva Inc
# Banco Santander SA
# Wienerberger AG
# Renault SA
# Carnival PLC
# Royal Caribbean Cruises Ltd
# JPMorgan Chase & Co
# Citigroup Inc
# Credit Agricole SA
# Morgan Stanley
# BNP Paribas
# Goldman Sachs Group Inc
# Societe Generale SA
# Postmedia Network Canada Corp
# Danone SA
# Deutsche Lufthansa AG
# HelloFresh SE
# Electricite De France SA
# Meta Platforms, Inc.
# Drax Group PLC
# AIG
